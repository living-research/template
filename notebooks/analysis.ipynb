# %% [markdown]
# # [Project Title]
#
# > One-line description of the research question.
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ORG_NAME/REPO_NAME/blob/main/notebooks/analysis.ipynb)
# [![View Findings](https://img.shields.io/badge/findings-live-teal)](https://ORG_NAME.github.io/REPO_NAME/)

# %% [markdown]
# ## Setup

# %%
# Clone repo and install dependencies
# !git clone --depth 1 https://github.com/ORG_NAME/REPO_NAME.git /content/REPO_NAME
# %cd /content/REPO_NAME
# !pip install -q -r requirements.txt

import sys
sys.path.insert(0, 'scripts')
from colab_utils import publish_artifacts, save_notebook

# %% [markdown]
# ## Data

# %%
# Load raw data
# data = pd.read_csv('data/raw/...')

# %% [markdown]
# ## Analysis

# %%
# Your analysis here
# Write outputs to results/ and docs/data/
#
# results/       — plots, models, intermediate outputs
# docs/data/     — data that the findings page reads at runtime

# %% [markdown]
# ## Publish
#
# Push results and findings data back to the repo. The findings page updates automatically via GitHub Pages.

# %%
# Save this notebook's current state
save_notebook('analysis.ipynb')

# Push results + docs/data + notebook to GitHub
publish_artifacts('update results and findings data')
